# %%
# tuple is immutable collection of data contains elemets which  can be treated  individualy or as a group
# it can be a hetrogenous, homogenous 
# a tuple is group of elements which is seprated by coma

t1=('a','b','c','d','e')
type(t1)
# Out:
# tuple

# %%
t2=("a",) # consider as tuple
t3=("a") # consider as string
print(type(t2))
print(type(t3))
# Out:
# <class 'tuple'>
# <class 'str'>

# %%
# empty tuple
t4=tuple()
type(t4)
# Out:
# tuple

# %%
# indexing using
t1[0]
# Out:
# 'a'

# %%
# slicing
t1[0:3]
t1=('a','b','c','d','e')

# %%
t1=("A",)+t1[1:]
t1
# Out:
# ('A', 'b', 'c', 'd', 'e')

# %%
#lexiographically order is used in dictionary and tuple follow this

# %%
m=["moneys",'honey']
x,y=m
print(x)
print(y)
# Out:
# moneys
# honey

# %%
m=["moneys",'honey']
(x,y)=m
x,y=y,x
print(x)
print(y)
# Out:
# honey
# moneys

# %%
def funcs():
    return "python",20
funcs() # it return tuple if more then one value is returned by a function
# Out:
# ('python', 20)

# %%
def circleInfo(x):
    c=(2*3.1)*x
    a=3.14*x*x
    return c,a
circleInfo(10)
# Out:
# (62.0, 314.0)
