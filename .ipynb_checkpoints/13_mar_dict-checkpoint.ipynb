# %%
dict1={'name':"Gaurav"}
dict1[0]='45'
print(dict1)
# Out:
# {'name': 'Gaurav', 0: '45'}

# %%
  m={"one":"apple","two":"banana","three":"papaya"}

# %%
m={"one":"apple","two":"banana"}

# %%
len(m)
# Out:
# 2

# %%
"one" in m
# Out:
# True

# %%
"five" in m
# Out:
# False

# %%
m.clear()
print()

# %%
m={"one":"apple","two":"banana","three":"papaya"}
n=m.copy()
n
# Out:
# {'one': 'apple', 'two': 'banana', 'three': 'papaya'}

# %%
x = ('key1', 'key2', 'key3')
y = 0

thisdict = dict.fromkeys(x, y)

print(thisdict)
# Out:
# {'key1': 0, 'key2': 0, 'key3': 0}

# %%
# get function
# it return the value of given keys
n.get('one')
n.items()
# Out:
# dict_items([('one', 'apple'), ('two', 'banana'), ('three', 'papaya')])

# %%
for key,value in n.items():
    print(f"key {key} and value {value}")
# Out:
# keys one and value apple
# keys two and value banana
# keys three and value papaya
