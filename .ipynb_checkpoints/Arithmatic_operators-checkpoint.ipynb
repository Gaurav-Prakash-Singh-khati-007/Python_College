# %%
# addition
2+3
# Out:
# 5

# %%
# Substraction
2-3
# Out:
# -1

# %%
# Division
2/3
# Out:
# 0.6666666666666666

# %%
# Integer division
4//3
# Out:
# 1

# %%
#  modular or remainder
2%3
# Out:
# 2

# %%
# Exponatial ** = Square
2**2
# Out:
# 4

# %%
# Multiplication *
2*3
# Out:
# 6
