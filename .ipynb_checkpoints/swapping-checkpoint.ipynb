# %%
a=int(input("Enter a number"))
b=int(input("Enter second number"))
print("\n")
print(f"Before swap number are {a} and {b}")
a,b=b,a


print("\n")
print(f"After swap number are {a} and {b}")
# Out:
# Enter a number 10
# Enter second number 20
# Before swap number are 10 and 20
#
#
#
#
# After swap number are 20 and 10
