# %%
# Comparison (Relational) Operators  returns boolean value either True or False

# %%
# equal to operator
5==5
# Out:
# True

# %%
# Not Equal to Operators 
5!=4
# Out:
# True

# %%
# less then 
5<6
# Out:
# True

# %%
# Greater then 
6>5
# Out:
# True

# %%
# Less then or equal to 
5<=6
# Out:
# True

# %%
# Greater or equal to
5>=5
# Out:
# True
