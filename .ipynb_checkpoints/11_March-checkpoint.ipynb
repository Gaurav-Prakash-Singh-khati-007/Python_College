# %% [markdown]
# ### Passing list as a function

# %%
def fruits(fru):
    for fruit in fru:
        print(fruit,end=' ') # end='' used as end then  at end of once print 
fruit=['Mango','Apple','Grapes']
fruits(fruit)
# Out:
# Mango Apple Grapes

# %%
print('Mango','Apple','Grapes',end=' ')
print('Mango','Apple','Grapes',end=' ')
print('Mango','Apple','Grapes',end=' ')
print('Mango','Apple','Grapes',end=' ')
print('Mango','Apple','Grapes',end=' ')
print('Mango','Apple','Grapes',end=' ')
# Out:
# Mango Apple Grapes Mango Apple Grapes Mango Apple Grapes Mango Apple Grapes Mango Apple Grapes Mango Apple Grapes

# %%
# BY defaut the print function add the new line  charchter in

# %%
# f string
name="Gaurav Khati"
age=26
city="Ramanagar"
print(f"Name:{name} and his age is Age:{age-10} and lives in city={city}")
# Out:
# Name:Gaurav Khati and his age is Age:16 and lives in city=RAMANAGAR
